# %%
df = pd.read_csv('bike-sharing-demand/train.csv',parse_dates = ['datetime'],index_col = 0)

# %%
df['year'] = df.index.year
df['Month'] = df.index.month
df['day'] = df.index.day
df['week'] = df.index.week
df['Hour'] = df.index.hour
df['Minute'] = df.index.minute

# %%
df = df.drop(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8e9f070c657c> in <module>
# ----> 1 df = df.drop(index)
#
# NameError: name 'index' is not defined

# %%
df.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'count', 'year',
#        'Month', 'day', 'week', 'Hour', 'Minute'],
#       dtype='object')

# %%
df.drop('Minute',axis = 1,inplace=True)

# %%
df.iloc[:,0]
# Out:
# datetime
# 2011-01-01 00:00:00    1
# 2011-01-01 01:00:00    1
# 2011-01-01 02:00:00    1
# 2011-01-01 03:00:00    1
# 2011-01-01 04:00:00    1
#                       ..
# 2012-12-19 19:00:00    4
# 2012-12-19 20:00:00    4
# 2012-12-19 21:00:00    4
# 2012-12-19 22:00:00    4
# 2012-12-19 23:00:00    4
# Name: season, Length: 10886, dtype: int64

# %%
test = df['count']
df.drop('count',axis=1,inplace=True)
train = df

# %%
train
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-19 19:00:00       4        0           1        1  15.58  19.695
# 2012-12-19 20:00:00       4        0           1        1  14.76  17.425
# 2012-12-19 21:00:00       4        0           1        1  13.94  15.910
# 2012-12-19 22:00:00       4        0           1        1  13.94  17.425
# 2012-12-19 23:00:00       4        0           1        1  13.12  16.665
#
#                      humidity  windspeed  casual  registered  year  Month  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(train,test,test_size = 0.3,random_state = 7)

# %%
# !pip install xgboost

# %%
import xgboost as xgb
regressor = xgb.XGBRegressor(n_estimators = 100, max_depth =5,booster = 'gbtree',n_jobs =-1)

# %%
regressor
# Out:
# XGBRegressor(base_score=None, booster='gbtree', colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=None, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=None, max_delta_step=None, max_depth=5,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=-1, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=None)

# %%
regressor.fit(X_train,Y_train,eval_set = [(X_train,Y_train),(X_test,Y_test)])
# Out:
# [0]	validation_0-rmse:185.68477	validation_1-rmse:185.87089
# [1]	validation_0-rmse:130.97089	validation_1-rmse:131.63832
# [2]	validation_0-rmse:92.60344	validation_1-rmse:93.64578
# [3]	validation_0-rmse:65.59147	validation_1-rmse:66.71433
# [4]	validation_0-rmse:46.54026	validation_1-rmse:47.79961
# [5]	validation_0-rmse:33.15451	validation_1-rmse:34.39301
# [6]	validation_0-rmse:23.83091	validation_1-rmse:25.11594
# [7]	validation_0-rmse:17.30381	validation_1-rmse:18.65107
# [8]	validation_0-rmse:12.83998	validation_1-rmse:14.35074
# [9]	validation_0-rmse:9.82633	validation_1-rmse:11.47446
# [10]	validation_0-rmse:7.85615	validation_1-rmse:9.58815
# [11]	validation_0-rmse:6.62235	validation_1-rmse:8.32404
# [12]	validation_0-rmse:5.80940	validation_1-rmse:7.64314
# [13]	validation_0-rmse:5.29378	validation_1-rmse:7.17885
# [14]	validation_0-rmse:4.95454	validation_1-rmse:6.79690
# [15]	validation_0-rmse:4.72982	validation_1-rmse:6.54521
# ...
